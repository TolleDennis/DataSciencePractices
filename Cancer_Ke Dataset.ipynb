# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=UserWarning)
warnings.simplefilter(action="ignore", category=RuntimeWarning)

# %%
# pd.set_option('display.max_rows', 500)
# pd.set_option('display.max_columns', 500)
# pd.set_option('display.width', 1000)

# %%
#Loading of the cancer raw uncleaned dataset
cancer_data = pd.read_csv("Cancer_Ke_RawData.csv")
cancer_data.head(10)
# Out:
#   Facility_Details-_1_Facility_Name  Facility_Details-_2_MFL_Number  \
# 0                      Embu Level 5                           12004
# 1  Embu Provincial General Hospital                           12004
# 2  Embu provincial general hospital                           12004
# 3                      Embu level 5                           12004
# 4  Embu Provincial General Hospital                           12004
# 5  Embu provincial general hospital                           12004
# 6            Embu level 5 hospital                            12004
# 7            Embu level 5 hospital                            12004
# 8  Embu Provincial General Hospital                           12004
# 9            Embu level 5 hospital                            12004
#
#    Facility_Details-_3_Facility_Level Facility_Details-_4_County       Ward  \
# 0                                   5                       Embu  Kirimari
# ...

# %%
#Exploration of the column MFL number for the value counts for each unique no.
cancer_data[["Facility_Details-_2_MFL_Number",]].value_counts()
# Out:
# Facility_Details-_2_MFL_Number
# 12004                             560
# 14178                             323
# 14831                             289
# 14706                             163
# 12413                             120
# 12790                              74
# 15568                              53
# 15074                              46
# 14834                              37
# 17164                              18
# 16464                              17
# 11289                              10
# 18546                               7
# 11740                               2
# 14813                               2
# 12719                               2
# 18210                               1
# 2                                   1
# 14501                               1
# 1235                                1
# 12345                               1
# 12005                               1
# 11861                               1
# 11435                               1
# ...

# %%
#Exploration of column county value counts
cancer_data["Facility_Details-_4_County"].value_counts()
# Out:
# Kericho      902
# Embu         798
# Mombasa       18
# Bomet         10
# Kiambu         1
# Kirinyaga      1
# Nyamira        1
# Narok          1
# Nakuru         1
# Busia          1
# Name: Facility_Details-_4_County, dtype: int64

# %%
#Exploration of column marital status value counts
cancer_data["Patients_Details-_9a_Marital_Status"].value_counts()
# Out:
# Married_Mono    1171
# Unknown          285
# Single           141
# Widowed           95
# Separated         17
# Married_Poly      13
# Divorced           7
# Other              5
# Name: Patients_Details-_9a_Marital_Status, dtype: int64

# %%
#Exploration of column Educational level value counts
cancer_data["Patients_Details-_11_Education_Level"].value_counts()
# Out:
# Not_ndicated    1118
# Primary          336
# Secondary        168
# Diploma           47
# None              37
# Other             13
# Certificate        8
# Bachelors          5
# Masters_1          1
# Masters            1
# Name: Patients_Details-_11_Education_Level, dtype: int64

# %%
#Exploration of column Occupation value counts
cancer_data["Patients_Details-_12a_Occupation"].value_counts()
# Out:
# Farmer              424
# 99                  217
# Farmer              120
# farmer               36
# Housewife            34
#                    ...
# Mason                 1
# Nurse                 1
# Student               1
# security officer      1
# ICT                   1
# Name: Patients_Details-_12a_Occupation, Length: 117, dtype: int64

# %%
#Exploration of column county of residence value counts
cancer_data["Patients_Details-_14a_County_of_Residence"].value_counts()
# Out:
# Kericho            560
# Embu               531
# Bomet              237
# Kirinyaga          159
# Tharaka_Nithi       73
# Nyamira             33
# Nakuru              29
# Narok               24
# Meru                15
# Kisii               11
# Mombasa             10
# Kisumu               9
# Nandi                9
# Kitui                8
# Kilifi               5
# Machakos             4
# Muranga              3
# Nyeri                3
# Kajiado              2
# Trans_Nzoia          1
# Kiambu               1
# Migori               1
# Vihiga               1
# Tana_River           1
# Makueni              1
# Kwale                1
# Garissa              1
# Elgeyo_Marakwet      1
# Name: Patients_Details-_14a_County_of_Residence, dtype: int64

# %%
#Exploration of column county ward of residence value counts
cancer_data["Patients_Details-_14c_Ward_of_Residence"].value_counts()
# Out:
# 99             73
# Litein         55
# Mwea           26
# Kirimari       25
# Nginda         25
#                ..
# Lelmokwo        1
# mindililwet     1
# tebesonik       1
# injipiship      1
# Ward            1
# Name: Patients_Details-_14c_Ward_of_Residence, Length: 661, dtype: int64

# %%
cancer_data["Ward"].value_counts()
# Out:
# Kirimari         424
# Litein           301
# Kipchebor        237
# Kapkatet         152
# Kirimari         136
#                 ...
# kapkatet           1
# Kaptebengwo        1
# Kimulot            1
# Kedowa/kimugu      1
# Ward               1
# Name: Ward, Length: 97, dtype: int64

# %%
#Exploration of column smoking status value counts
cancer_data["Patient_Lifestyle-_20a_Smoking_Status"].value_counts()
# Out:
# 4    863
# 1    602
# 3    205
# 2     64
# Name: Patient_Lifestyle-_20a_Smoking_Status, dtype: int64

# %%
#Exploration of column alcohol drinking status value counts
cancer_data["Patient_Lifestyle-_21a_Alcohol_Drinking_Status"].value_counts()
# Out:
# 4    847
# 1    552
# 3    264
# 2     71
# Name: Patient_Lifestyle-_21a_Alcohol_Drinking_Status, dtype: int64

# %%
#Exploration of column sexual history status value counts
cancer_data["Patient_Lifestyle-Other_Patient_Lifestyle-_23a_Any_sexual_history"].value_counts()
# Out:
# No     1546
# Yes      90
# Name: Patient_Lifestyle-Other_Patient_Lifestyle-_23a_Any_sexual_history, dtype: int64

# %%
#Exploration of column type of cancer value counts
cancer_data["Patients_Details-_16_Type_of_Cancer"].value_counts()
# Out:
# Other                                 321
# Esophageal_cancer                     265
# Prostate_cancer                       222
# Cervical_cancer                       208
# Breast_cancer                         207
#                                      ...
# Kaposis_sarcoma Other                   1
# Cervical_cancer Other                   1
# Cervical_cancer Uterine_cancer          1
# Gastric_cancer Ovarian_cancer           1
# Burkits_lymphoma Cholangicarcinoma      1
# Name: Patients_Details-_16_Type_of_Cancer, Length: 64, dtype: int64

# %%
#Exploration of column any vaccination value counts
cancer_data["Patient_Lifestyle-Other_Patient_Lifestyle-_23b_Any_Vaccination"].value_counts()
# Out:
# No     1621
# Yes      11
# Name: Patient_Lifestyle-Other_Patient_Lifestyle-_23b_Any_Vaccination, dtype: int64

# %%
#Exploration of column screening history value counts
cancer_data["Patient_Lifestyle-Other_Patient_Lifestyle-_23c_Any_Screening_history_on"].value_counts()
# Out:
# No     1286
# Yes     333
# Name: Patient_Lifestyle-Other_Patient_Lifestyle-_23c_Any_Screening_history_on, dtype: int64

# %%
#Exploration of column any pre existing condition value counts
cancer_data["Patient_Lifestyle-Other_Patient_Lifestyle-_24a_Any_pre_existing_conditio"].value_counts()
# Out:
# No     1378
# Yes     211
# Name: Patient_Lifestyle-Other_Patient_Lifestyle-_24a_Any_pre_existing_conditio, dtype: int64

# %%
#Exploration of column any basis of diagnosis value counts
cancer_data["Tumor_Details-_27a_Basis_of_Diagnosis"].value_counts()
# Out:
# 2            604
# 6            528
# 7             54
# 5             50
# 1             41
#             ...
# 0 2 3 4        1
# 0 2 3 4 5      1
# 4 2 3          1
# 0 2 3          1
# 5 6 7          1
# Name: Tumor_Details-_27a_Basis_of_Diagnosis, Length: 121, dtype: int64

# %%
#Exploration of column tumor grade value counts
cancer_data["Tumor_Details-_29a_Tumor_Grade"].value_counts()
# Out:
# 5    1397
# 2     146
# 3     101
# 1      73
# 4      17
# Name: Tumor_Details-_29a_Tumor_Grade, dtype: int64

# %%
#Exploration of column type of cancer cells value counts
cancer_data["Tumor_Details-_29b_Type_of_Cells"].value_counts()
# Out:
# 5    1704
# 1      15
# 2      12
# 4       2
# 3       1
# Name: Tumor_Details-_29b_Type_of_Cells, dtype: int64

# %%
#Exploration of column stumor stage value counts
cancer_data["Tumor_Details-_30_Tumor_Stage"].value_counts()
# Out:
# 5    1456
# 4     135
# 3      79
# 2      37
# 0      14
# 1      13
# Name: Tumor_Details-_30_Tumor_Stage, dtype: int64

# %%
#Exploration of column initial dx value counts
cancer_data["Diagnosis_and_Treatment-_32_Year_of_initial_Dx"].value_counts()
# Out:
# 2020          480
# 2019          351
# 2018          247
# 2021          215
# 2017          129
# 99            121
# 2016          103
# 2015           29
# 2014           10
# 2010            9
# 2012            9
# 2011            6
# 2013            4
# 201,            3
# 1               2
# 2008            2
# 2009            2
# 2006            1
# 2007            1
# 20202021        1
# 2028            1
# 5017            1
# 2002            1
# 9               1
# 2001            1
# 1.3.2021        1
# 12 09 2021      1
# 1993            1
# 2000            1
# Name: Diagnosis_and_Treatment-_32_Year_of_initial_Dx, dtype: int64

# %%
#Exploration of column final confirmed dx value counts
cancer_data["Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx"].value_counts()
# Out:
# CA cervix                                                           70
# Breast cancer                                                       59
# CA oesophagus                                                       56
# Prostate cancer                                                     44
# Cervical cancer                                                     32
#                                                                     ..
# Esophagus,invasive poorly differentiated squamous cell carcinoma     1
# Epithelioid gastro-intestinal stromal tumour                         1
# Endocervical adenocarcinoma                                          1
# Cancer of oesophagus                                                 1
# None                                                                 1
# Name: Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx, Length: 848, dtype: int64

# %%
#Exploration of column staus value counts
cancer_data["Diagnosis_and_Treatment-_39a_Status"].value_counts()
# Out:
# Alive    1208
# Dead      524
# Name: Diagnosis_and_Treatment-_39a_Status, dtype: int64

# %%
#splitting of the dataset to get a sample of Embu county
Cancer_Embu_county = cancer_data[cancer_data["Facility_Details-_4_County"]=="Embu"]
Cancer_Embu_county.head(20)
Cancer_Embu_county.shape
# Out:
# (798, 77)

# %%
#splitting of the dataset to get a sample of Kericho county
Cancer_Kericho_county = cancer_data[cancer_data["Facility_Details-_4_County"]=="Kericho"]
Cancer_Kericho_county.head(20)
Cancer_Kericho_county.shape
# Out:
# (902, 77)

# %%
#joining the sample of both Embu and Kericho county
Cancer_Embu_Kericho_county = (cancer_data.apply(lambda row: row[cancer_data['Facility_Details-_4_County'].isin(['Embu','Kericho'])]))
Cancer_Embu_Kericho_county.head(20)
Cancer_Embu_Kericho_county.shape
# Out:
# (1700, 77)

# %%
#columns distribution info
Cancer_Embu_Kericho_county.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1700 entries, 0 to 1732
# Data columns (total 77 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Facility_Details-_1_Facility_Name                                         1700 non-null   object
#  1   Facility_Details-_2_MFL_Number                                            1700 non-null   int64
#  2   Facility_Details-_3_Facility_Level                                        1700 non-null   int64
#  3   Facility_Details-_4_County                                                1700 non-null   object
#  4   Ward                                                                      1700 non-null   object
#  5   _5a_Date_file_opened                                                      1700 non-null   object
# ...

# %%
print(Cancer_Embu_Kericho_county["Tumor_Details-_30_Tumor_Stage"].value_counts())
# Out:
# 5    1437
# 4     131
# 3      77
# 2      34
# 1      12
# 0       9
# Name: Tumor_Details-_30_Tumor_Stage, dtype: int64

# %%
Cancer_Embu_Kericho_county["Patients_Details-_12a_Occupation"].value_counts()
# Out:
# Farmer              423
# 99                  213
# Farmer              120
# Housewife            34
# farmer               32
#                    ...
# Mason                 1
# Nurse                 1
# Student               1
# security officer      1
# Casual worker         1
# Name: Patients_Details-_12a_Occupation, Length: 114, dtype: int64

# %%
# Delete columns containing either 70% or more than 70% NaN Values in Embu Kericho county dataset
perc = 70.0
min_count =  int(((100-perc)/100)*Cancer_Embu_Kericho_county.shape[0] + 1)
Cancer_Embu_Kericho_county = Cancer_Embu_Kericho_county.dropna( axis=1, thresh=min_count)
Cancer_Embu_Kericho_county.head()
# Out:
#   Facility_Details-_1_Facility_Name  Facility_Details-_2_MFL_Number  \
# 0                      Embu Level 5                           12004
# 1  Embu Provincial General Hospital                           12004
# 2  Embu provincial general hospital                           12004
# 3                      Embu level 5                           12004
# 4  Embu Provincial General Hospital                           12004
#
#    Facility_Details-_3_Facility_Level Facility_Details-_4_County       Ward  \
# 0                                   5                       Embu  Kirimari
# 1                                   5                       Embu   Kirimari
# 2                                   5                       Embu   Kirimari
# 3                                   5                       Embu  Kirimari
# 4                                   5                       Embu   Kirimari
#
#   _5a_Date_file_opened _5b_Date_of_Last_entry  Patients_Details-_7b_Age  \
# ...

# %%
Cancer_Embu_Kericho_county.isnull().sum()
# Out:
# Facility_Details-_1_Facility_Name                                              0
# Facility_Details-_2_MFL_Number                                                 0
# Facility_Details-_3_Facility_Level                                             0
# Facility_Details-_4_County                                                     0
# Ward                                                                           0
# _5a_Date_file_opened                                                           0
# _5b_Date_of_Last_entry                                                         0
# Patients_Details-_7b_Age                                                      13
# Patients_Details-_9a_Marital_Status                                            0
# Patients_Details-_10_Parity                                                  775
# Patients_Details-_11_Education_Level                                           0
# Patients_Details-_12a_Occupation                                             588
# ...

# %%
#Facility name data cleanup on Embu Kericho Cancer dataset
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("fort", case=False), 'Facility_Details-_1_Facility_Name'] = 'Forttenan Sub District Hospital'
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("aic", case=False), 'Facility_Details-_1_Facility_Name'] = 'AIC Litein Mission Hospital'
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("lit", case=False), 'Facility_Details-_1_Facility_Name'] = 'AIC Litein Mission Hospital'
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("sig", case=False), 'Facility_Details-_1_Facility_Name'] = 'Sigowet Sub-District Hospital'
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("lon", case=False), 'Facility_Details-_1_Facility_Name'] = 'Londiani District Hospital'
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("kap", case=False), 'Facility_Details-_1_Facility_Name'] = 'Kapkatet District Hospital'
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("kcr", case=False), 'Facility_Details-_1_Facility_Name'] = 'Kericho District Hospital'
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("kericho county", case=False), 'Facility_Details-_1_Facility_Name'] = 'Kericho District Hospital'
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("kericho nur", case=False), 'Facility_Details-_1_Facility_Name'] = 'Medistar Hospital Kericho Limited'
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("kericho nur", case=False), 'Facility_Details-_1_Facility_Name'] = 'Kericho Nursing Home'
Cancer_Embu_Kericho_county[["Facility_Details-_2_MFL_Number","Facility_Details-_1_Facility_Name"]].value_counts().index
# Out:
# MultiIndex([( 14178,         'AIC Litein Mission Hospital'),
#             ( 14831,           'Kericho District Hospital'),
#             ( 12004,    'Embu provincial general hospital'),
#             ( 14706,          'Kapkatet District Hospital'),
#             ( 12004,                        'Embu level 5'),
#             ( 12004,    'Embu Provincial General Hospital'),
#             ( 12413,            'Consolata kyeni hospital'),
#             ( 12790,              'Embu Children Hospital'),
#             ( 12004,              'Embu level 5 hospital '),
#             ( 15568,       'Sigowet Sub-District Hospital'),
#             ( 12413,           'Consolata kyeni hospital '),
#             ( 15074,          'Londiani District Hospital'),
#             ( 12004,               'Embu level 5 hospital'),
#             ( 14834,   'Medistar Hospital Kericho Limited'),
#             ( 12004,            'Embu level five hospital'),
# ...

# %%
#replacing wrongly inputed data on facility name with the correct one and dropping mfl 1235,renaming 
Cancer_Embu_Kericho_county.drop(Cancer_Embu_Kericho_county[Cancer_Embu_Kericho_county['Facility_Details-_2_MFL_Number'] == 1235 ].index, inplace = True)
der = Cancer_Embu_Kericho_county[(Cancer_Embu_Kericho_county["Facility_Details-_2_MFL_Number"] == 14831) & (Cancer_Embu_Kericho_county["Facility_Details-_1_Facility_Name"] == "Medistar Hospital Kericho Limited")].replace("Medistar Hospital Kericho Limited","Kericho District Hospital") 
Cancer_Embu_Kericho_county["Facility_Details-_2_MFL_Number"].replace(14813,14831,inplace= True) 
Cancer_Embu_Kericho_county.update(der)
Cancer_Embu_Kericho_county[["Facility_Details-_2_MFL_Number","Facility_Details-_3_Facility_Level"]] = Cancer_Embu_Kericho_county[["Facility_Details-_2_MFL_Number","Facility_Details-_3_Facility_Level"]].astype(int)

# %%
#Facility name data cleanup on Embu Cancer dataset
emb = Cancer_Embu_Kericho_county[(Cancer_Embu_Kericho_county["Facility_Details-_2_MFL_Number"] == 12790) & (Cancer_Embu_Kericho_county["Facility_Details-_1_Facility_Name"] == "Embu Level 5 Hospital")].replace("Embu Level 5 Hospital","Embu Children Hospital") 
Cancer_Embu_Kericho_county["Facility_Details-_1_Facility_Name"].replace("Mohammed Gichunge","Embu Children Hospital",inplace= True) 
Cancer_Embu_Kericho_county.update(emb)
Cancer_Embu_Kericho_county["Facility_Details-_2_MFL_Number"].replace((112004,12005),12004,inplace= True) 
emb1 = Cancer_Embu_Kericho_county[(Cancer_Embu_Kericho_county["Facility_Details-_2_MFL_Number"] == 17164) & (Cancer_Embu_Kericho_county["Facility_Details-_1_Facility_Name"] == "Embu Level 5 Hospital")].replace("Embu Level 5 Hospital","Embu-Mbeere Hospice") 
Cancer_Embu_Kericho_county.update(emb1)
emb2 = Cancer_Embu_Kericho_county[(Cancer_Embu_Kericho_county["Facility_Details-_2_MFL_Number"] == 12004) & (Cancer_Embu_Kericho_county["Facility_Details-_1_Facility_Name"] == "Embu Level 5 Hospital")].replace("Embu Level 5 Hospital","Embu-Mbeere Hospice") 
Cancer_Embu_Kericho_county.update(emb2)
emb3 = Cancer_Embu_Kericho_county[(Cancer_Embu_Kericho_county["Facility_Details-_2_MFL_Number"] == 12004) & (Cancer_Embu_Kericho_county["Facility_Details-_1_Facility_Name"] == "Embu Children Hospital")].replace("Embu Children Hospital","Embu Level 5 Hospital") 
Cancer_Embu_Kericho_county.update(emb3)
emb4 = Cancer_Embu_Kericho_county[(Cancer_Embu_Kericho_county["Facility_Details-_2_MFL_Number"] == 12004) & (Cancer_Embu_Kericho_county["Facility_Details-_1_Facility_Name"] == "Embu")].replace("Embu","Embu Level 5 Hospital") 
Cancer_Embu_Kericho_county.update(emb4)
emb5 = Cancer_Embu_Kericho_county[(Cancer_Embu_Kericho_county["Facility_Details-_2_MFL_Number"] == 12004) & (Cancer_Embu_Kericho_county["Facility_Details-_1_Facility_Name"] == "Embu-Mbeere Hospice")].replace("Embu-Mbeere Hospice","Embu Level 5 Hospital") 
Cancer_Embu_Kericho_county.update(emb5)
emb6 = Cancer_Embu_Kericho_county[(Cancer_Embu_Kericho_county["Facility_Details-_2_MFL_Number"] == 18546) & (Cancer_Embu_Kericho_county["Facility_Details-_1_Facility_Name"] == "Ishiara Sub-County Hospital")].replace("Ishiara Sub-County Hospital","County Medical Center - Embu Ltd") 
emb7 = Cancer_Embu_Kericho_county[(Cancer_Embu_Kericho_county["Facility_Details-_2_MFL_Number"] == 12719) & (Cancer_Embu_Kericho_county["Facility_Details-_1_Facility_Name"] == "Ishiara Sub-County Hospital")].replace("Ishiara Sub-County Hospital","Runyenjes County Hospital") 
Cancer_Embu_Kericho_county["Facility_Details-_1_Facility_Name"].replace("Mohammed Gichunge","Embu Children Hospital",inplace= True) 
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("level", case=False), 'Facility_Details-_1_Facility_Name'] = 'Embu Level 5 Hospital'
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("g", case=False), 'Facility_Details-_1_Facility_Name'] = 'Embu Level 5 Hospital'
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("prov", case=False), 'Facility_Details-_1_Facility_Name'] = 'Embu Level 5 Hospital'
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("con", case=False), 'Facility_Details-_1_Facility_Name'] = 'Consolata Kyeni Hospital'
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("embu chi", case=False), 'Facility_Details-_1_Facility_Name'] = 'Embu Children Hospital'
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("chi", case=False), 'Facility_Details-_1_Facility_Name'] = 'Embu Children Hospital'
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("county", case=False), 'Facility_Details-_1_Facility_Name'] = 'Ishiara Sub-County Hospital'
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("runy", case=False), 'Facility_Details-_1_Facility_Name'] = 'Runyenjes Sub County Hospital'
Cancer_Embu_Kericho_county.loc[Cancer_Embu_Kericho_county['Facility_Details-_1_Facility_Name'].str.contains("mbeere", case=False), 'Facility_Details-_1_Facility_Name'] = 'Embu-Mbeere Hospice'

# %%
Cancer_Embu_Kericho_county["Facility_Details-_2_MFL_Number"] = Cancer_Embu_Kericho_county["Facility_Details-_2_MFL_Number"].astype(int)
Cancer_Embu_Kericho_county[["Facility_Details-_1_Facility_Name","Facility_Details-_2_MFL_Number"]].value_counts()
# Out:
# Facility_Details-_1_Facility_Name  Facility_Details-_2_MFL_Number
# Embu Level 5 Hospital              12004                             562
# AIC Litein Mission Hospital        14178                             314
# Kericho District Hospital          14831                             290
# Kapkatet District Hospital         14706                             160
# Consolata Kyeni Hospital           12413                             120
# Embu Children Hospital             12790                              72
# Embu Level 5 Hospital              15568                              53
# Londiani District Hospital         15074                              46
# Medistar Hospital Kericho Limited  14834                              37
# Embu-Mbeere Hospice                17164                              18
# Ishiara Sub-County Hospital        16464                              17
#                                    18546                               7
# ...

# %%
emb8 = Cancer_Embu_Kericho_county[(Cancer_Embu_Kericho_county["Facility_Details-_2_MFL_Number"] == 12719) & (Cancer_Embu_Kericho_county["Facility_Details-_1_Facility_Name"] == "Ishiara Sub-County Hospital")].replace("Ishiara Sub-County Hospital","Runyenjes County Hospital") 
Cancer_Embu_Kericho_county.update(emb8)

# %%
emb9 = Cancer_Embu_Kericho_county[(Cancer_Embu_Kericho_county["Facility_Details-_2_MFL_Number"] == 18546) & (Cancer_Embu_Kericho_county["Facility_Details-_1_Facility_Name"] == "Ishiara Sub-County Hospital")].replace("Ishiara Sub-County Hospital","County Medical Center - Embu Ltd") 
Cancer_Embu_Kericho_county.update(emb9)

# %%
Cancer_Embu_Kericho_county.drop(["Patients_Details-_12a_Occupation","Patients_Details-_15_Nearest_Land_mark",'Patients_Details-Sub_county_of_Residence_Embu'],axis = 1 ,inplace= True)

# %%
Cancer_Embu_Kericho_county['Patients_Details-_9a_Marital_Status'].value_counts()
# Out:
# Married_Mono    1151
# Unknown          280
# Single           136
# Widowed           94
# Separated         16
# Married_Poly      11
# Divorced           7
# Other              4
# Name: Patients_Details-_9a_Marital_Status, dtype: int64

# %%
Cancer_Embu_Kericho_county.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1699 entries, 0 to 1731
# Data columns (total 46 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Facility_Details-_1_Facility_Name                                         1699 non-null   object
#  1   Facility_Details-_2_MFL_Number                                            1699 non-null   float64
#  2   Facility_Details-_3_Facility_Level                                        1699 non-null   float64
#  3   Facility_Details-_4_County                                                1699 non-null   object
#  4   Ward                                                                      1699 non-null   object
#  5   _5a_Date_file_opened                                                      1699 non-null   object
# ...

# %%
#Dropping unused features in patient location columns
Cancer_Embu_Kericho_county.drop(Cancer_Embu_Kericho_county.columns[[3,4,5,6,9,10,11,14,12,15,16,17]],axis=1, inplace= True)
Cancer_Embu_Kericho_county.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1699 entries, 0 to 1731
# Data columns (total 34 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Facility_Details-_1_Facility_Name                                         1699 non-null   object
#  1   Facility_Details-_2_MFL_Number                                            1699 non-null   float64
#  2   Facility_Details-_3_Facility_Level                                        1699 non-null   float64
#  3   Patients_Details-_7b_Age                                                  1686 non-null   float64
#  4   Patients_Details-_9a_Marital_Status                                       1699 non-null   object
#  5   Patients_Details-_14a_County_of_Residence                                 1699 non-null   object
# ...

# %%
#Dropping of more columns containing null values
Cancer_Embu_Kericho_county.drop(['Diagnosis_and_Treatment-_38b_Other',"Diagnosis_and_Treatment-_39b_Remission","Diagnosis_and_Treatment-_35_Dx_Radiology"],axis = 1,inplace= True)
Cancer_Embu_Kericho_county.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1699 entries, 0 to 1731
# Data columns (total 31 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Facility_Details-_1_Facility_Name                                         1699 non-null   object
#  1   Facility_Details-_2_MFL_Number                                            1699 non-null   float64
#  2   Facility_Details-_3_Facility_Level                                        1699 non-null   float64
#  3   Patients_Details-_7b_Age                                                  1686 non-null   float64
#  4   Patients_Details-_9a_Marital_Status                                       1699 non-null   object
#  5   Patients_Details-_14a_County_of_Residence                                 1699 non-null   object
# ...

# %%
Cancer_Embu_Kericho_County_copy = Cancer_Embu_Kericho_county.copy()
Cancer_Embu_Kericho_County_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1699 entries, 0 to 1731
# Data columns (total 31 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Facility_Details-_1_Facility_Name                                         1699 non-null   object
#  1   Facility_Details-_2_MFL_Number                                            1699 non-null   float64
#  2   Facility_Details-_3_Facility_Level                                        1699 non-null   float64
#  3   Patients_Details-_7b_Age                                                  1686 non-null   float64
#  4   Patients_Details-_9a_Marital_Status                                       1699 non-null   object
#  5   Patients_Details-_14a_County_of_Residence                                 1699 non-null   object
# ...

# %%
Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_36_Dx_Laboratory"].value_counts()
# Out:
# Histology_Biopsy                                      557
# Cytology_Blood                                        282
# Biochemistry_Serum                                    242
# Cytology_Blood Histology_Biopsy                        63
# Cytology_Blood Biochemistry_Serum                      49
# Histology_Biopsy Cytology_Blood                        25
# Biochemistry_Serum Histology_Biopsy                    25
# Biochemistry_Serum Cytology_Blood                      21
# Histology_Biopsy Biochemistry_Serum                    20
# Cytology_Blood Biochemistry_Serum Histology_Biopsy      5
# Pap_smear                                               5
# Histology_Biopsy Pap_smear                              4
# Cytology_Blood Histology_Biopsy Biochemistry_Serum      3
# Bone_marrow                                             3
# Histology_Biopsy Bone_marrow                            3
# Pap_smear Histology_Biopsy                              2
# ...

# %%
#Changing the dx confrimation date to year only
import warnings
warnings.filterwarnings('ignore')
Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37b_Date_of_Confirmation'] = pd.to_datetime(Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37b_Date_of_Confirmation'], errors='coerce').dt.year

# %%
Cancer_Embu_Kericho_County_copy.dropna(subset =["Diagnosis_and_Treatment-_37b_Date_of_Confirmation"],how = "all",inplace = True)

# %%
Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_37b_Date_of_Confirmation"].isnull().sum()
# Out:
# 0

# %%
#replacing wrongly formated year of dx
Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_32_Year_of_initial_Dx"].replace(["20202021","1.3.2021"],"2021",inplace= True)
Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_32_Year_of_initial_Dx"].replace(["5017","1.3.2021"],"2017",inplace= True)
Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_32_Year_of_initial_Dx"].replace(["201,"],"2017",inplace= True)
Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_32_Year_of_initial_Dx"].replace(["9"],"99",inplace= True)

# %%
Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_32_Year_of_initial_Dx"].value_counts()
Cancer_Embu_Kericho_County_copy = pd.DataFrame(Cancer_Embu_Kericho_County_copy)

# %%
Cancer_Embu_Kericho_County_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1698 entries, 0 to 1731
# Data columns (total 31 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Facility_Details-_1_Facility_Name                                         1698 non-null   object
#  1   Facility_Details-_2_MFL_Number                                            1698 non-null   float64
#  2   Facility_Details-_3_Facility_Level                                        1698 non-null   float64
#  3   Patients_Details-_7b_Age                                                  1685 non-null   float64
#  4   Patients_Details-_9a_Marital_Status                                       1698 non-null   object
#  5   Patients_Details-_14a_County_of_Residence                                 1698 non-null   object
# ...

# %%
Cancer_Embu_Kericho_County_copy1 = Cancer_Embu_Kericho_County_copy.copy()
Cancer_Embu_Kericho_County_copy1.head(100)
# Out:
#    Facility_Details-_1_Facility_Name  Facility_Details-_2_MFL_Number  \
# 0              Embu Level 5 Hospital                         12004.0
# 1              Embu Level 5 Hospital                         12004.0
# 2              Embu Level 5 Hospital                         12004.0
# 3              Embu Level 5 Hospital                         12004.0
# 4              Embu Level 5 Hospital                         12004.0
# ..                               ...                             ...
# 95             Embu Level 5 Hospital                         12004.0
# 96             Embu Level 5 Hospital                         12004.0
# 97             Embu Level 5 Hospital                         12004.0
# 98             Embu Level 5 Hospital                         12004.0
# 99             Embu Level 5 Hospital                         12004.0
#
#     Facility_Details-_3_Facility_Level  Patients_Details-_7b_Age  \
# 0                                  5.0                      68.0
# ...

# %%
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Esopha", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Esophageal_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Pros", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Prostate_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Cervi", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Cervical_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Breast", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Breast_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Gastr", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Gastric_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Colorec", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Colorectal_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Pancr", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Pancreatic_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Lung", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Lung_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Leuk", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Leukemia'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Ovar", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Ovarian_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Live", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Liver_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Lary", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Laryngeal_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Bladd", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Bladder_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Endom", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Endometrial_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Skin", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Skin_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Non-Hodgki", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Non-Hodgkins_lymphoma'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Nasoph", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Nasopharyngeal_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Thyroid", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Thyroid_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Hodgkins", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Hodgkins_lymphoma'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Vulv", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Vulvar_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Cholangi", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Cholangicarcinoma'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Kapo", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Kaposis_sarcoma'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Hypoph", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Hypopharyngeal_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Eye", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Eye_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Peni", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Penile_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("My", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Multiple_Myeloma'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("stom", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Stomach_Cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("colo", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Colon_Cancer'

# %%
Cancer_Embu_Kericho_County_copy.info()
Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_38_Rx'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1698 entries, 0 to 1731
# Data columns (total 31 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Facility_Details-_1_Facility_Name                                         1698 non-null   object
#  1   Facility_Details-_2_MFL_Number                                            1698 non-null   float64
#  2   Facility_Details-_3_Facility_Level                                        1698 non-null   float64
#  3   Patients_Details-_7b_Age                                                  1685 non-null   float64
#  4   Patients_Details-_9a_Marital_Status                                       1698 non-null   object
#  5   Patients_Details-_14a_County_of_Residence                                 1698 non-null   object
# ...

# %%
Cancer_Embu_Kericho_County_copy.drop(Cancer_Embu_Kericho_County_copy.columns[[1,]],inplace= True , axis = 1)
Cancer_Embu_Kericho_County_copy.head(10)
# Out:
#   Facility_Details-_1_Facility_Name  Facility_Details-_3_Facility_Level  \
# 0             Embu Level 5 Hospital                                 5.0
# 1             Embu Level 5 Hospital                                 5.0
# 2             Embu Level 5 Hospital                                 5.0
# 3             Embu Level 5 Hospital                                 5.0
# 4             Embu Level 5 Hospital                                 5.0
# 5             Embu Level 5 Hospital                                 5.0
# 6             Embu Level 5 Hospital                                 5.0
# 7             Embu Level 5 Hospital                                 5.0
# 8             Embu Level 5 Hospital                                 5.0
# 9             Embu Level 5 Hospital                                 5.0
#
#    Patients_Details-_7b_Age Patients_Details-_9a_Marital_Status  \
# 0                      68.0                        Married_Mono
# ...

# %%
#Data cleanup on final dx confirmed
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Esopha", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Esophageal_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Pros", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Prostate_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Cervi", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Cervical_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Breast", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Breast_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Gastric", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Gastric_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Colorec", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Colorectal_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Pancr", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Pancreatic_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Lung", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Lung_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Leuk", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Leukemia'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Ovar", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Ovarian_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Live", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Liver_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Lary", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Laryngeal_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Bladd", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Bladder_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Endom", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Endometrial_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Skin", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Skin_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Non-Hodgki", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Non-Hodgkins_lymphoma'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Nasoph", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Nasopharyngeal_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Thyroid", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Thyroid_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Hodgki", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Hodgkins_lymphoma'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Vulv", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Vulvar_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Cholang", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Cholangicarcinoma'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Kapos", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Kaposis_sarcoma'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Hypop", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Hypopharyngeal_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Eye", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Eye_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Peni", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Penile_cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("Myeloma", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Multiple_Myeloma'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("stom", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Stomach_Cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("colo", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Colon_Cancer'
Cancer_Embu_Kericho_County_copy.loc[Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].str.contains("anae", case=False),  'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'] = 'Anaemia'

# %%
Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].value_counts()
# Out:
# Esophageal_cancer                            254
# Prostate_cancer                              212
# Cervical_cancer                              206
# Breast_cancer                                183
# Gastric_cancer                                53
#                                             ...
# Large B cell lympoma                           1
# Invasive squamous carcinoma                    1
# Verrucous carcinoma                            1
# Metastatic invisible ductal carcinoma          1
# Soft tissue and connective tissue sarcoma      1
# Name: Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx, Length: 335, dtype: int64

# %%
#Cancer_Embu_Kericho_County_copy.dropna(how = 'any',inplace=True)

# %%
#preprocessing 
Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].value_counts()
# Out:
# Esophageal_cancer                            254
# Prostate_cancer                              212
# Cervical_cancer                              206
# Breast_cancer                                183
# Gastric_cancer                                53
#                                             ...
# Large B cell lympoma                           1
# Invasive squamous carcinoma                    1
# Verrucous carcinoma                            1
# Metastatic invisible ductal carcinoma          1
# Soft tissue and connective tissue sarcoma      1
# Name: Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx, Length: 335, dtype: int64

# %%
#Splitting the data for patients with Lung cancer only
Lung_Cancer_Embu_Kericho = Cancer_Embu_Kericho_County_copy.iloc[list(Cancer_Embu_Kericho_County_copy["Patients_Details-_16_Type_of_Cancer"]== "Lung_cancer")]
Lung_Cancer_Embu_Kericho[['Facility_Details-_3_Facility_Level','Facility_Details-_1_Facility_Name']].value_counts()
# Out:
# Facility_Details-_3_Facility_Level  Facility_Details-_1_Facility_Name
# 4.0                                 Kericho District Hospital            13
# 5.0                                 AIC Litein Mission Hospital          11
#                                     Embu Level 5 Hospital                 6
# 4.0                                 Kapkatet District Hospital            5
#                                     Londiani District Hospital            3
#                                     Consolata Kyeni Hospital              1
#                                     Ishiara Sub-County Hospital           1
# dtype: int64

# %%
Cervical_Cancer_Embu_Kericho = Cancer_Embu_Kericho_County_copy.iloc[list(Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx"]== "Cervical_cancer")]
Liver_Cancer_Embu_Kericho = Cancer_Embu_Kericho_County_copy.iloc[list(Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx"]== "Liver_cancer")]
Esophageal_Cancer_Embu_Kericho = Cancer_Embu_Kericho_County_copy.iloc[list(Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx"]== "Esophageal_cancer")]
Breast_Cancer_Embu_Kericho = Cancer_Embu_Kericho_County_copy.iloc[list(Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx"]== "Breast_cancer")]
Prostate_Cancer_Embu_Kericho = Cancer_Embu_Kericho_County_copy.iloc[list(Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx"]== "Prostate_cancer")]
Gastric_Cancer_Embu_Kericho = Cancer_Embu_Kericho_County_copy.iloc[list(Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx"]== "Gastric_cancer")]
Stomach_Cancer_Embu_Kericho = Cancer_Embu_Kericho_County_copy.iloc[list(Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx"]== "Stomach_Cancer")]
Colon_Cancer_Embu_Kericho = Cancer_Embu_Kericho_County_copy.iloc[list(Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx"]== "Colon_Cancer")]
Pancreatic_Cancer_Embu_Kericho =Cancer_Embu_Kericho_County_copy.iloc[list(Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx"]== "Pancreatic_cancer")]
Ovarian_Cancer_Embu_Kericho = Cancer_Embu_Kericho_County_copy.iloc[list(Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx"]== "Ovarian_cancer")]
Leukemia_Embu_Kericho = Cancer_Embu_Kericho_County_copy.iloc[list(Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx"]== "Leukemia")]


print(Prostate_Cancer_Embu_Kericho['Facility_Details-_1_Facility_Name'].value_counts())
print('*****************')
print(Breast_Cancer_Embu_Kericho['Facility_Details-_1_Facility_Name'].value_counts())
print('*****************')
print(Cervical_Cancer_Embu_Kericho['Facility_Details-_1_Facility_Name'].value_counts())
print('*****************')
print(Esophageal_Cancer_Embu_Kericho['Facility_Details-_1_Facility_Name'].value_counts())
print('*****************')
# Out:
# Embu Level 5 Hospital                96
# Consolata Kyeni Hospital             31
# Kericho District Hospital            19
# AIC Litein Mission Hospital          18
# Embu Children Hospital               17
# Kapkatet District Hospital            9
# Medistar Hospital Kericho Limited     8
# Londiani District Hospital            5
# County Medical Center - Embu Ltd      4
# Ishiara Sub-County Hospital           3
# Embu-Mbeere Hospice                   1
# Forttenan Sub District Hospital       1
# Name: Facility_Details-_1_Facility_Name, dtype: int64
# *****************
# Embu Level 5 Hospital                96
# AIC Litein Mission Hospital          20
# Kericho District Hospital            19
# Embu-Mbeere Hospice                   9
# Embu Children Hospital                9
# Consolata Kyeni Hospital              9
# Kapkatet District Hospital            9
# Londiani District Hospital            4
# Medistar Hospital Kericho Limited     4
# Ishiara Sub-County Hospital           2
# ...

# %%
Cancer_Embu_Kericho_County_copy.head()
#Cancer_Embu_Kericho_County_copy['Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'].value_counts()
# Out:
#   Facility_Details-_1_Facility_Name  Facility_Details-_3_Facility_Level  \
# 0             Embu Level 5 Hospital                                 5.0
# 1             Embu Level 5 Hospital                                 5.0
# 2             Embu Level 5 Hospital                                 5.0
# 3             Embu Level 5 Hospital                                 5.0
# 4             Embu Level 5 Hospital                                 5.0
#
#    Patients_Details-_7b_Age Patients_Details-_9a_Marital_Status  \
# 0                      68.0                        Married_Mono
# 1                      90.0                        Married_Mono
# 2                      54.0                        Married_Mono
# 3                      52.0                        Married_Mono
# 4                      52.0                        Married_Mono
#
#   Patients_Details-_14a_County_of_Residence  \
# 0                                      Embu
# 1                                      Embu
# ...

# %%
#Visualizing the Final DX Cancer Cases

# %%
lx = sns.countplot(x = 'Patients_Details-_14a_County_of_Residence',data = Lung_Cancer_Embu_Kericho,hue ='Diagnosis_and_Treatment-_39a_Status' )
lx.set_xticklabels(lx.get_xticklabels(), rotation=40, ha="right")
plt.title('Lung Cancer Embu Kericho County Hospitals')
plt.show()

# %%
bx = sns.countplot(x = 'Patients_Details-_14a_County_of_Residence',data = Breast_Cancer_Embu_Kericho,hue ='Diagnosis_and_Treatment-_39a_Status' )
bx.set_xticklabels(bx.get_xticklabels(), rotation=40, ha="right")
plt.title('Breast Cancer Embu Kericho County Hospitals')
plt.tight_layout()
plt.show()

# %%
ex = sns.countplot(x = 'Patients_Details-_14a_County_of_Residence',data = Esophageal_Cancer_Embu_Kericho,hue ='Diagnosis_and_Treatment-_39a_Status' )
ex.set_xticklabels(ex.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.title('Esophageal Cancer Embu Kericho County Hospitals')
plt.show()

# %%
sx = sns.countplot(x = 'Patients_Details-_14a_County_of_Residence',data = Stomach_Cancer_Embu_Kericho,hue ='Diagnosis_and_Treatment-_39a_Status' )
sx.set_xticklabels(sx.get_xticklabels(), rotation=40, ha="right")
plt.title('Stomach Cancer Embu Kericho County Hospitals')
plt.tight_layout()
plt.show()

# %%
gx = sns.countplot(x = 'Patients_Details-_14a_County_of_Residence',data = Gastric_Cancer_Embu_Kericho,hue ='Diagnosis_and_Treatment-_39a_Status' )
gx.set_xticklabels(gx.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.title('Gastric Cancer Embu Kericho County Hospitals')
plt.show()

# %%
cx = sns.countplot(x = 'Patients_Details-_14a_County_of_Residence',data = Colon_Cancer_Embu_Kericho,hue ='Diagnosis_and_Treatment-_39a_Status' )
cx.set_xticklabels(cx.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.title('Colon Cancer Embu Kericho County Hospitals')
plt.show()

# %%
px = sns.countplot(x = 'Patients_Details-_14a_County_of_Residence',data = Prostate_Cancer_Embu_Kericho,hue ='Diagnosis_and_Treatment-_39a_Status' )
px.set_xticklabels(px.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.title('Prostrate Cancer Embu Kericho County Hospitals')
plt.show()

# %%
prx = sns.countplot(x = 'Patients_Details-_14a_County_of_Residence',data = Pancreatic_Cancer_Embu_Kericho,hue ='Diagnosis_and_Treatment-_39a_Status' )
prx.set_xticklabels(prx.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.title('Pancreatic Cancer Embu Kericho County Hospitals')
plt.show()

# %%
lkx = sns.countplot(x = 'Patients_Details-_14a_County_of_Residence',data = Leukemia_Embu_Kericho,hue ='Diagnosis_and_Treatment-_39a_Status' )
lkx.set_xticklabels(lkx.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.title('Leukemia Embu Kericho County Hospitals')
plt.show()

# %%
ox = sns.countplot(x = 'Patients_Details-_14a_County_of_Residence',data = Ovarian_Cancer_Embu_Kericho,hue ='Diagnosis_and_Treatment-_39a_Status' )
ox.set_xticklabels(ox.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.title('Ovarian Cancer Embu Kericho County Hospitals')
plt.show()

# %%
lvx = sns.countplot(x = 'Patients_Details-_14a_County_of_Residence',data = Liver_Cancer_Embu_Kericho,hue ='Diagnosis_and_Treatment-_39a_Status' )
lvx.set_xticklabels(lvx.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.title('Liver Cancer Embu Kericho County Hospitals')
plt.show()

# %%
sns.swarmplot( y ='Facility_Details-_3_Facility_Level',x ='Tumor_Details-_30_Tumor_Stage' ,hue ='Diagnosis_and_Treatment-_39a_Status', data = Cancer_Embu_Kericho_County_copy)
#cs.set_xticklabels(cs.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.title('Liver Cancer Embu Kericho County Hospitals')
plt.show()

# %%
xx = sns.barplot(x = "Patients_Details-_9a_Marital_Status",y = "Patients_Details-_7b_Age", hue = "Diagnosis_and_Treatment-_39a_Status", data = Cancer_Embu_Kericho_County_copy)
xx.set_xticklabels(xx.get_xticklabels(), rotation=40, ha="right")
plt.title('Cancer Mortality Rate Distribution as per Marital Status')
print(xx)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#Filtered Cancer cases for Machine learning modellling
filtered_Cases = ['Breast_cancer','Esophageal_cancer','Prostate_cancer','Cervical_cancer']
filtered_Cancer_Cases = Cancer_Embu_Kericho_County_copy[Cancer_Embu_Kericho_County_copy["Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx"].isin(filtered_Cases)]
filtered_Cancer_Cases.head(10)
# Out:
#    Facility_Details-_1_Facility_Name  Facility_Details-_3_Facility_Level  \
# 0              Embu Level 5 Hospital                                 5.0
# 1              Embu Level 5 Hospital                                 5.0
# 5              Embu Level 5 Hospital                                 5.0
# 6              Embu Level 5 Hospital                                 5.0
# 8              Embu Level 5 Hospital                                 5.0
# 9              Embu Level 5 Hospital                                 5.0
# 10             Embu Level 5 Hospital                                 5.0
# 11               Embu-Mbeere Hospice                                 2.0
# 12  County Medical Center - Embu Ltd                                 3.0
# 14               Embu-Mbeere Hospice                                 2.0
#
#     Patients_Details-_7b_Age Patients_Details-_9a_Marital_Status  \
# 0                       68.0                        Married_Mono
# ...

# %%
xo = sns.countplot(x = "Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx",hue = "Patients_Details-_9a_Marital_Status", data = filtered_Cancer_Cases)
xo.set_xticklabels(xo.get_xticklabels(), rotation=40, ha="right")
plt.title('Final_Confirmed_Dx Cancer as per Marital Status')
print(xo)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
filtered_Cancer_Cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 855 entries, 0 to 1729
# Data columns (total 30 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Facility_Details-_1_Facility_Name                                         855 non-null    object
#  1   Facility_Details-_3_Facility_Level                                        855 non-null    float64
#  2   Patients_Details-_7b_Age                                                  847 non-null    float64
#  3   Patients_Details-_9a_Marital_Status                                       855 non-null    object
#  4   Patients_Details-_14a_County_of_Residence                                 855 non-null    object
#  5   Patients_Details-_16_Type_of_Cancer                                       855 non-null    object
# ...

# %%
x = filtered_Cancer_Cases.drop(filtered_Cancer_Cases.columns[[0,1,4,5,6,10,11,15,21,22,23,24,27,28,29]],axis=1)
x.reset_index(drop=True)
x = x.dropna()
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 590 entries, 0 to 1728
# Data columns (total 15 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Patients_Details-_7b_Age                                                  590 non-null    float64
#  1   Patients_Details-_9a_Marital_Status                                       590 non-null    object
#  2   Patients_Details-_19a_Family_history_of_cancer                            590 non-null    object
#  3   Patient_Lifestyle-_20a_Smoking_Status                                     590 non-null    float64
#  4   Patient_Lifestyle-_21a_Alcohol_Drinking_Status                            590 non-null    float64
#  5   Patient_Lifestyle-Other_Patient_Lifestyle-_23c_Any_Screening_history_on   590 non-null    object
# ...

# %%
x['Diagnosis_and_Treatment-_36_Dx_Laboratory'].value_counts()
# Out:
# Histology_Biopsy                                      242
# Cytology_Blood                                        147
# Biochemistry_Serum                                     95
# Cytology_Blood Biochemistry_Serum                      25
# Cytology_Blood Histology_Biopsy                        20
# Biochemistry_Serum Histology_Biopsy                    14
# Biochemistry_Serum Cytology_Blood                      14
# Histology_Biopsy Cytology_Blood                        11
# Pap_smear                                               4
# Histology_Biopsy Biochemistry_Serum                     4
# Histology_Biopsy Pap_smear                              3
# Cytology_Blood Biochemistry_Serum Histology_Biopsy      3
# Pap_smear Histology_Biopsy                              2
# Cytology_Blood Histology_Biopsy Biochemistry_Serum      2
# Cytology_Blood Pap_smear Histology_Biopsy               1
# Histology_Biopsy Bone_marrow                            1
# ...

# %%
x.to_csv('filtered_Cancer.csv')
x
# Out:
#       Patients_Details-_7b_Age Patients_Details-_9a_Marital_Status  \
# 0                         68.0                        Married_Mono
# 10                        73.0                        Married_Mono
# 11                        29.0                              Single
# 12                        61.0                        Married_Mono
# 14                        39.0                           Separated
# ...                        ...                                 ...
# 1711                      54.0                        Married_Mono
# 1716                      36.0                        Married_Mono
# 1721                      65.0                        Married_Mono
# 1725                      61.0                        Married_Mono
# 1728                      51.0                        Married_Mono
#
#      Patients_Details-_19a_Family_history_of_cancer  \
# 0                                                No
# 10                                         Not_Sure
# ...

# %%
#Creating Column Transformers
from sklearn.compose import ColumnTransformer
from sklearn.datasets import fetch_openml
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder,LabelEncoder,StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
from sklearn.feature_extraction.text import CountVectorizer

objectList = x.select_dtypes(include = "object").columns
print(objectList)

le = LabelEncoder()

for feat in objectList:
    x[feat] = le.fit_transform(x[feat].astype(str))

x.head()
# Out:
# Index(['Patients_Details-_9a_Marital_Status',
#        'Patients_Details-_19a_Family_history_of_cancer',
#        'Patient_Lifestyle-Other_Patient_Lifestyle-_23c_Any_Screening_history_on',
#        'Patient_Lifestyle-Other_Patient_Lifestyle-_24a_Any_pre_existing_conditio',
#        'Patient_Lifestyle-Other_Patient_Lifestyle-_25a_Any_Opportunistic_conditi',
#        'Tumor_Details-_27a_Basis_of_Diagnosis',
#        'Diagnosis_and_Treatment-_36_Dx_Laboratory',
#        'Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx'],
#       dtype='object')
#     Patients_Details-_7b_Age  Patients_Details-_9a_Marital_Status  \
# 0                       68.0                                    1
# 10                      73.0                                    1
# 11                      29.0                                    4
# 12                      61.0                                    1
# 14                      39.0                                    3
#
# ...

# %%
#Splitting the data to target and feature variables
X = x.drop('Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx',axis = 1).reset_index(drop=True)
y = x["Diagnosis_and_Treatment-_37a_Final_Confirmed_Dx"].reset_index(drop=True)

# %%
#Splitting the data to training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#modelling
ensemble = RandomForestClassifier()
ensemble.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#prediction
y_pred = ensemble.predict(X_test)
y_pred
# Out:
# array([2, 0, 3, 1, 2, 1, 2, 1, 0, 2, 2, 1, 2, 1, 1, 1, 0, 1, 2, 1, 2, 0,
#        0, 3, 1, 0, 2, 3, 0, 3, 2, 1, 2, 3, 2, 2, 3, 3, 2, 0, 1, 3, 0, 1,
#        1, 0, 0, 2, 3, 3, 3, 0, 2, 2, 0, 2, 2, 3, 0, 2, 0, 2, 3, 2, 2, 3,
#        2, 0, 2, 2, 1, 3, 2, 1, 2, 0, 3, 1, 2, 2, 2, 3, 0, 3, 2, 3, 2, 1,
#        2, 3, 3, 2, 2, 1, 0, 0, 0, 1, 1, 1, 2, 2, 0, 3, 3, 0, 0, 1, 0, 2,
#        0, 1, 3, 3, 3, 3, 0, 2])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(y_test,y_pred)
# Out:
# 0.5169491525423728

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[15,  7,  7,  2],
#        [ 3, 12,  8,  3],
#        [ 6,  2, 16,  4],
#        [ 3,  3,  9, 18]])

# %%
import pickle
pickle.dump(ensemble,open('cancer_1.pkl', 'wb'))
