# %%
import pandas as pd

# %%
xpoints = np.array([0,2,4,6,8])
ypoints = np.array([1,3,])

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import math

# %%
data_titanic = pd.read_csv("Titanic-Dataset.csv")

# %%
sns.scatterplot(x="Fare",y = "Age", hue = "Survived",data = data_titanic)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Age'>

# %%
data_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data_titanic["Age"] =data_titanic["Age"].fillna(int(data_titanic["Age"].mean()))
data_titanic.head()
# Out:
#    PassengerId  Survived   Age  SibSp  Parch     Fare
# 0            1         0  22.0      1      0   7.2500
# 1            2         1  38.0      1      0  71.2833
# 2            3         1  26.0      0      0   7.9250
# 3            4         1  35.0      1      0  53.1000
# 4            5         0  35.0      0      0   8.0500

# %%
data_titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# dtype: int64

# %%
print("The Number of passengers in original data: " +str(len(data_titanic.index)))
# Out:
# The Number of passengers in original data: 889

# %% [markdown]
# # Analyzing Data

# %%
sns.countplot(x="Survived", data = data_titanic)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Survived",hue ="SibSp", data = data_titanic)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.histplot(x="Survived",hue ="male", data = data_titanic2)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Count'>

# %%
sns.countplot(x="Survived",hue ="Parch", data = data_titanic)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="SibSp",hue ="Pclass", data = data_titanic)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
data_titanic["Age"].plot.hist(bins=10,figsize=(10,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data_titanic["Fare"].plot.hist(bins=10,figsize=(10,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data_titanic["SibSp"].plot.hist(bins = 15, figsize=(10,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data_titanic["Survived"].count()
# Out:
# 891

# %% [markdown]
# # Data Wrangling

# %%
data_titanic.isnull()
# Out:
#      PassengerId  Survived    Age  SibSp  Parch   Fare
# 0          False     False  False  False  False  False
# 1          False     False  False  False  False  False
# 2          False     False  False  False  False  False
# 3          False     False  False  False  False  False
# 4          False     False  False  False  False  False
# ..           ...       ...    ...    ...    ...    ...
# 886        False     False  False  False  False  False
# 887        False     False  False  False  False  False
# 888        False     False  False  False  False  False
# 889        False     False  False  False  False  False
# 890        False     False  False  False  False  False
#
# [889 rows x 6 columns]

# %%
data_titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(data_titanic.isnull(), yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x="Pclass", y ="Age",data = data_titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
data_titanic.drop("Cabin",axis =1,inplace = True)

# %%
data_titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
data_titanic.dropna(inplace=True)

# %%
data_titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
data_titanic.count()
# Out:
# PassengerId    889
# Survived       889
# Pclass         889
# Name           889
# Sex            889
# Age            889
# SibSp          889
# Parch          889
# Ticket         889
# Fare           889
# Embarked       889
# dtype: int64

# %%
data_titanic["PassengerId"].count()
# Out:
# 889

# %%
sns.heatmap(data_titanic.isnull(), yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
data_titanic.head(20)
# Out:
#     PassengerId  Survived        Age  SibSp  Parch     Fare
# 0             1         0  22.000000      1      0   7.2500
# 1             2         1  38.000000      1      0  71.2833
# 2             3         1  26.000000      0      0   7.9250
# 3             4         1  35.000000      1      0  53.1000
# 4             5         0  35.000000      0      0   8.0500
# 5             6         0  29.699118      0      0   8.4583
# 6             7         0  54.000000      0      0  51.8625
# 7             8         0   2.000000      3      1  21.0750
# 8             9         1  27.000000      0      2  11.1333
# 9            10         1  14.000000      1      0  30.0708
# 10           11         1   4.000000      1      1  16.7000
# 11           12         1  58.000000      0      0  26.5500
# 12           13         0  20.000000      0      0   8.0500
# 13           14         0  39.000000      1      5  31.2750
# 14           15         0  14.000000      0      0   7.8542
# ...

# %%
# pd.get_dummies(data_titanic["Sex"]
data_titanic.head()
# Out:
#    PassengerId  Survived   Age  SibSp  Parch     Fare
# 0            1         0  22.0      1      0   7.2500
# 1            2         1  38.0      1      0  71.2833
# 2            3         1  26.0      0      0   7.9250
# 3            4         1  35.0      1      0  53.1000
# 4            5         0  35.0      0      0   8.0500

# %%
Sex=pd.get_dummies(data_titanic["Sex"],drop_first = True)
Sex.head()
# Out:
#    male
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1

# %%
Embark = pd.get_dummies(data_titanic["Embarked"], drop_first= True)
Embark.head(10)
# Out:
#    Q  S
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  1
# 4  0  1
# 5  1  0
# 6  0  1
# 7  0  1
# 8  0  1
# 9  0  0

# %%
Pclass= pd.get_dummies(data_titanic["Pclass"],drop_first= True)
Pclass.head()
# Out:
#    2  3
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  0
# 4  0  1

# %%
data_titanic.drop(["Name","Ticket","Embarked","Pclass"], axis = 1,inplace = True)
data_titanic.head()
# Out:
#    PassengerId  Survived     Sex   Age  SibSp  Parch     Fare
# 0            1         0    male  22.0      1      0   7.2500
# 1            2         1  female  38.0      1      0  71.2833
# 2            3         1  female  26.0      0      0   7.9250
# 3            4         1  female  35.0      1      0  53.1000
# 4            5         0    male  35.0      0      0   8.0500

# %%
data_titanic.drop(["Sex"], axis = 1,inplace = True)
data_titanic.head()
# Out:
#    PassengerId  Survived   Age  SibSp  Parch     Fare
# 0            1         0  22.0      1      0   7.2500
# 1            2         1  38.0      1      0  71.2833
# 2            3         1  26.0      0      0   7.9250
# 3            4         1  35.0      1      0  53.1000
# 4            5         0  35.0      0      0   8.0500

# %%
data_titanic2 = pd.concat([data_titanic,Embark,Pclass,Sex], axis = 1)

# %%
data_titanic2.head(10)
# Out:
#    Survived   Age  SibSp  Parch     Fare  Q  S  2  3  male
# 0         0  22.0      1      0   7.2500  0  1  0  1     1
# 1         1  38.0      1      0  71.2833  0  0  0  0     0
# 2         1  26.0      0      0   7.9250  0  1  0  1     0
# 3         1  35.0      1      0  53.1000  0  1  0  0     0
# 4         0  35.0      0      0   8.0500  0  1  0  1     1
# 5         0  30.0      0      0   8.4583  1  0  0  1     1
# 6         0  54.0      0      0  51.8625  0  1  0  0     1
# 7         0   2.0      3      1  21.0750  0  1  0  1     1
# 8         1  27.0      0      2  11.1333  0  1  0  1     0
# 9         1  14.0      1      0  30.0708  0  0  1  0     0

# %%
data_titanic2=data_titanic2.rename(columns = {2:"2",3:"3"})
data_titanic2.head(20)
data_titanic2["Age"]= data_titanic2["Age"].round()
data_titanic2["Age"].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
data_titanic2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  889 non-null    int64
#  1   Age       889 non-null    float64
#  2   SibSp     889 non-null    int64
#  3   Parch     889 non-null    int64
#  4   Fare      889 non-null    float64
#  5   Q         889 non-null    uint8
#  6   S         889 non-null    uint8
#  7   2         889 non-null    uint8
#  8   3         889 non-null    uint8
#  9   male      889 non-null    uint8
# dtypes: float64(2), int64(3), uint8(5)
# memory usage: 78.3 KB

# %%
data_titanic2.describe()
# Out:
#          Survived         Age       SibSp       Parch        Fare           Q  \
# count  889.000000  889.000000  889.000000  889.000000  889.000000  889.000000
# mean     0.382452   29.708661    0.524184    0.382452   32.096681    0.086614
# std      0.486260   12.967368    1.103705    0.806761   49.697504    0.281427
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   22.000000    0.000000    0.000000    7.895800    0.000000
# 50%      0.000000   30.000000    0.000000    0.000000   14.454200    0.000000
# 75%      1.000000   35.000000    1.000000    0.000000   31.000000    0.000000
# max      1.000000   80.000000    8.000000    6.000000  512.329200    1.000000
#
#                 S           2           3        male
# count  889.000000  889.000000  889.000000  889.000000
# mean     0.724409    0.206974    0.552306    0.649044
# std      0.447063    0.405365    0.497536    0.477538
# ...

# %% [markdown]
# # Train Data

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X = data_titanic2.iloc[:,1:]
y = data_titanic2.iloc[:,0]

# %%
print(X)
print(y)
# Out:
#       Age  SibSp  Parch     Fare  Q  S  2  3  male
# 0    22.0      1      0   7.2500  0  1  0  1     1
# 1    38.0      1      0  71.2833  0  0  0  0     0
# 2    26.0      0      0   7.9250  0  1  0  1     0
# 3    35.0      1      0  53.1000  0  1  0  0     0
# 4    35.0      0      0   8.0500  0  1  0  1     1
# ..    ...    ...    ...      ... .. .. .. ..   ...
# 886  27.0      0      0  13.0000  0  1  1  0     1
# 887  19.0      0      0  30.0000  0  1  0  0     0
# 888  30.0      1      2  23.4500  0  1  0  1     0
# 889  26.0      0      0  30.0000  0  0  0  0     1
# 890  32.0      0      0   7.7500  1  0  0  1     1
#
# [889 rows x 9 columns]
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 889, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.33,random_state=1)

# %%
y_train.head(20)
# Out:
# 495    0
# 14     0
# 83     0
# 619    0
# 841    0
# 89     0
# 274    1
# 173    0
# 473    1
# 104    0
# 664    1
# 458    1
# 45     0
# 341    1
# 321    0
# 538    0
# 638    0
# 11     1
# 215    1
# 845    0
# Name: Survived, dtype: int64

# %%
X_train.head(20)
# Out:
#       Age  SibSp  Parch      Fare  Q  S  2  3  male
# 495  30.0      0      0   14.4583  0  0  0  1     1
# 14   14.0      0      0    7.8542  0  1  0  1     0
# 83   28.0      0      0   47.1000  0  1  0  0     1
# 619  26.0      0      0   10.5000  0  1  1  0     1
# 841  16.0      0      0   10.5000  0  1  1  0     1
# 89   24.0      0      0    8.0500  0  1  0  1     1
# 274  30.0      0      0    7.7500  1  0  0  1     0
# 173  21.0      0      0    7.9250  0  1  0  1     1
# 473  23.0      0      0   13.7917  0  0  1  0     0
# 104  37.0      2      0    7.9250  0  1  0  1     1
# 664  20.0      1      0    7.9250  0  1  0  1     1
# 458  50.0      0      0   10.5000  0  1  1  0     0
# 45   30.0      0      0    8.0500  0  1  0  1     1
# 341  24.0      3      2  263.0000  0  1  0  0     0
# 321  27.0      0      0    7.8958  0  1  0  1     1
# 538  30.0      0      0   14.5000  0  1  0  1     1
# 638  41.0      0      5   39.6875  0  1  0  1     0
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
logModel = LogisticRegression()

# %%
logModel.fit(X_train,y_train)
# Out:
# /home/twcodetech/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
Y_predict = logModel.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
acc_score = accuracy_score(y_test,Y_predict)
print(acc_score)
# Out:
# 0.826530612244898

# %%
import
